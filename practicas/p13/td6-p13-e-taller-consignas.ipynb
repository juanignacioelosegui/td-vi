# %% [markdown]
# Universidad Torcuato Di Tella
#
# Licenciatura en Tecnología Digital\
# **Tecnología Digital VI: Inteligencia Artificial**

# %% [markdown]
# # **Taller de word2vec**

# %% [markdown]
# Resolver las siguientes consignas.

# %% [markdown]
# ### **Consigna 1**
#
# > Leer la documentación oficial de `Word2Vec`, perteneciente al paquete `gensim`, utilizado en la T10, e indicar brevemente, en sus palabras, qué rol cumple cada uno de los siguientes parámetros que `Word2Vec` tiene disponibles. *Tip*: la documentación oficial se encuentra disponible [acá](https://radimrehurek.com/gensim/models/word2vec.html).

# %% [markdown]
# * `vector_size`: COMPLETAR.
#
# * `window`: COMPLETAR.
#
# * `min_count`: COMPLETAR.
#
# * `negative`: COMPLETAR.

# %% [markdown]
# ### **Consigna 2**
#
# > El dataset que se encuentra en el campus posee una variable `title` con titulos de productos de un retailer online. Utilizando esta variable, entrenar dos modelos de word2vec, uno con una ventana pequeña y otro con una ventana grande. *Tip*: para definir qué es "pequeña" y qué es "grande", tener en cuenta el largo general de los títulos.

# %%
# CARGAR DATOS
import pandas as pd

# Cargamos los datos de los titulos.
titulos_data = pd.read_csv('titulos.csv')

# Dividimos los datos de entrenamiento de los de evaluación.
train_data = titulos_data[titulos_data['ROW_ID'].isna()]
eval_data = titulos_data[titulos_data['ROW_ID'].notna()]
del titulos_data
gc.collect()

# %%
# COMPLETAR CON EL MODELO

# %% [markdown]
# ### **Consigna 3**
#
# > Evaluar si los vectores encontrados, mediante los dos modelos anteriores, tienen o no sentido; es decir, si los mismos logran captar bien la similitud entre títulos. Ojo: se pide entre títulos, no entre palabras. *Tip*: crear un vector por título promediando los vectores de sus palabras; [este sitio web](https://dylancastillo.co/nlp-snippets-cluster-documents-using-word2vec/) puede ser de ayuda.

# %%
# COMPLETAR
