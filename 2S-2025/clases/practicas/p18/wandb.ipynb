# %%
import wandb
import numpy as np
import time

# %%
#wandb.login()

# %%
wandb.login(key = "") # OJO con compartir esto!

# %%
wandb.init(
    project="td6", 
    entity="", 
    name="experimento_2",
    config = {
        "learning_rate": 0.01,
        "epochs": 10
    }
)

# %%
for epoch in range(100):

    loss = np.random.rand() * (100 - epoch) # / 5
    
    print("Epoch", epoch, "Loss", loss)
    wandb.log({"epoch": epoch, "loss":loss})

    # time.sleep(5)

# %%
wandb.finish()
