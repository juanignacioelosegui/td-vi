# %%
import numpy as np
import time

# %%
v1 = np.random.rand(1000000, 1)
v2 = np.random.rand(1000000, 1)

# %%
# Scaling Vector - For loop
start = time.process_time()
v1_scaled = np.zeros((1000000, 1))

for i in range(len(v1)):
    v1_scaled[i] = 2 * v1[i]

end = time.process_time()
print("Scaling vector Answer = " + str(v1_scaled))
print("Time taken = " + str((end - start)) + " seg")

#Scaling Vector - Vectorized
start = time.process_time()
v1_scaled = np.zeros((1000000, 1))

v1_scaled = 2 * v1

end = time.process_time()

print("Scaling vector Answer = " + str(v1_scaled))
print("Time taken = " + str((end - start)) + " seg")
# Out:
# Scaling vector Answer = [[1.97999207]
#  [0.38825489]
#  [0.54007902]
#  ...
#  [1.13926306]
#  [1.26949087]
#  [0.96571282]]
# Time taken = 2.2618373839999997 seg
# Scaling vector Answer = [[1.97999207]
#  [0.38825489]
#  [0.54007902]
#  ...
#  [1.13926306]
#  [1.26949087]
#  [0.96571282]]
# Time taken = 0.005163942999999449 seg

# %%
# Dot product For loop
start = time.process_time()
product = 0

for i in range(len(v1)):
    product += v1[i] * v2[i]

end = time.process_time()

print("Dot product Answer = " + str(product))
print("Time taken = " + str((end - start)) + " seg")

#Dot product Vectorized
start = time.process_time()
product = 0

product = np.dot(v1.T, v2)

end = time.process_time()

print("Dot product Answer = " + str(product))
print("Time taken = " + str((end - start)) + " seg")
# Out:
# Dot product Answer = [250233.72187142]
# Time taken = 3.702499857000003 seg
# Dot product Answer = [[250233.72187142]]
# Time taken = 0.004028506000004484 seg

# %%
#Element wise mutliplication For loop
start = time.process_time()

answer = np.zeros((1000000, 1))

for i in range(len(v1)):
    answer[i] = v1[i] * v2[i]

end = time.process_time()

print("Element Wise answer = " + str(answer))
print("Time taken = " + str((end - start)) + " seg")

#Element wise multiplication Vectorized
start = time.process_time()

answer = np.zeros((1000000, 1))

answer = ##COMPLETAR

end = time.process_time()

print("Element Wise answer = " + str(answer))
print("Time taken = " + str((end - start)) + " seg")
# Out:
# Element Wise answer = [[0.73112484]
#  [0.1332956 ]
#  [0.26044971]
#  ...
#  [0.13874012]
#  [0.05853311]
#  [0.39007032]]
# Time taken = 1.6309246750000028 seg
# Element Wise answer = [[0.73112484]
#  [0.1332956 ]
#  [0.26044971]
#  ...
#  [0.13874012]
#  [0.05853311]
#  [0.39007032]]
# Time taken = 0.005595337999999117 seg

# %%
#Element wise matrix multiplication For loop

m1 = np.random.rand(1000, 1000)
m2 = np.random.rand(1000, 1000)
answer = np.zeros((1000, 1000))

start = time.process_time()

for i in range(m1.shape[0]):
    for j in range(m1.shape[1]):
        answer[i, j] = m1[i, j] * m2[i, j]

end = time.process_time()

print("Element Wise Matrix answer = " + str(answer))
print("Time taken = " + str((end - start)) + " seg")

#Element wise matrix multiplication Vectorized
answer = np.zeros((1000, 1000))

start = time.process_time()

answer = ##COMPLETAR

end = time.process_time()

print("Element Wise Matrix answer = " + str(answer))
print("Time taken = " + str((end - start)) + " seg")
# Out:
# Element Wise Matrix answer = [[9.27257109e-02 2.63200157e-01 9.71236544e-02 ... 9.03344260e-02
#   5.09803998e-01 5.09295491e-02]
#  [6.98839772e-02 9.89850541e-02 8.63645619e-02 ... 3.25035058e-04
#   4.25579107e-01 5.87568430e-02]
#  [1.20906736e-01 2.18593806e-01 3.03698320e-01 ... 5.28200573e-01
#   2.02744073e-01 6.12705756e-02]
#  ...
#  [2.02361090e-01 1.74258063e-01 5.38363213e-02 ... 6.44439124e-01
#   3.41871961e-02 8.27772637e-01]
#  [1.21402265e-01 3.85202873e-01 5.13083962e-01 ... 4.28907453e-01
#   3.81846240e-01 9.81407638e-02]
#  [3.75033868e-02 1.39041550e-01 2.33374184e-01 ... 8.67260748e-01
#   5.49181670e-03 2.64160193e-02]]
# Time taken = 0.6779740480000029 seg
# Element Wise Matrix answer = [[9.27257109e-02 2.63200157e-01 9.71236544e-02 ... 9.03344260e-02
#   5.09803998e-01 5.09295491e-02]
#  [6.98839772e-02 9.89850541e-02 8.63645619e-02 ... 3.25035058e-04
#   4.25579107e-01 5.87568430e-02]
#  [1.20906736e-01 2.18593806e-01 3.03698320e-01 ... 5.28200573e-01
#   2.02744073e-01 6.12705756e-02]
#  ...
#  [2.02361090e-01 1.74258063e-01 5.38363213e-02 ... 6.44439124e-01
#   3.41871961e-02 8.27772637e-01]
#  [1.21402265e-01 3.85202873e-01 5.13083962e-01 ... 4.28907453e-01
#   3.81846240e-01 9.81407638e-02]
#  [3.75033868e-02 1.39041550e-01 2.33374184e-01 ... 8.67260748e-01
#   5.49181670e-03 2.64160193e-02]]
# Time taken = 0.002207195000003992 seg
